# %% [markdown]
# # Természetes nyelvfeldolgozás
# # PTE Gépi tanulás III.
#
# ## 1. Előadás: gyakorlati feladatok
# ### 2024. február 21.

# %% [markdown]
# #RAJZOLJUK LE A KONCEPCIÓT!!!

# %% [markdown]
# #Hírkereső alkalmazás
#
# hírek letöltése különböző weblapokról

# %%
# Importált modulok
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd
import time  # Új modul importálása a késleltetéshez

# %%
# Táblák definiálása
web_pages = pd.DataFrame(columns=['url', 'title'])
articles = pd.DataFrame(columns=['page_url', 'url', 'title', 'text'])

# %%
# Adatok gyűjtése és mentése
urls = ['https://index.hu/', 'https://origo.hu/', 'https://www.portfolio.hu/', 'https://www.napi.hu/', 'https://444.hu/', 'https://24.hu/', 'https://telex.hu/', 'https://mno.hu/', 'https://magyarnemzet.hu/', 'https://444.hu/']
keyword = 'nato'

for url in urls:
    try:
        # Kérés küldése az URL-re
        r = requests.get(url)
        # Hiba ellenőrzése
        r.raise_for_status()

        # BeautifulSoup objektum létrehozása a HTML-ből
        soup = BeautifulSoup(r.content, 'html.parser')

        # A weboldal címe
        title = soup.find('title').text.strip()

        # Oldal hozzáadása a web_pages táblához
        web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)

        # Cikkek keresése
        for link in soup.find_all('a'):
            # A cikk URL-je
            article_url = link.get('href')

            # Ellenőrzi, hogy a kulcsszó szerepel-e a link szövegében
            if article_url is not None and keyword in link.text.lower():

                # Ciklus az articles táblához
                try:
                    # Kérés küldése a cikk URL-jére
                    article_r = requests.get(article_url)
                    # Hiba ellenőrzése
                    article_r.raise_for_status()

                    # BeautifulSoup objektum létrehozása a cikk HTML-jéből
                    article_soup = BeautifulSoup(article_r.content, 'html.parser')

                    # A cikk szövege
                    article_text = article_soup.get_text(separator='\n')

                    # Cikkek hozzáadása az articles táblához
                    articles = articles.append({'page_url': url, 'url': article_url, 'title': link.text.strip(), 'text': article_text}, ignore_index=True)
                except requests.exceptions.RequestException as e:
                    # Hibaüzenet kiírása
                    print(f"Hiba a cikk letöltése közben: {e}")
                    # Tovább a következő cikkre
                    continue

    except requests.exceptions.RequestException as e:
        # Hibaüzenet kiírása
        print(f"Hiba a weboldal letöltése közben: {e}")
        # Tovább a következő weboldalra
        continue

    # Késleltetés az újabb kérések között
    time.sleep(1)  # 1 másodperces késleltetés
# Out:
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
# Hiba a cikk letöltése közben: Invalid URL '/itthon/2024/02/vallott-az-egykori-nato-foparancsnok-sorosek-magyarorszagon-is-beavatkoztak-a-valasztasokba': No scheme supplied. Perhaps you meant https:///itthon/2024/02/vallott-az-egykori-nato-foparancsnok-sorosek-magyarorszagon-is-beavatkoztak-a-valasztasokba?
# Hiba a cikk letöltése közben: Invalid URL '/utazas/2024/02/ahol-csak-lehetett-emberek-kapaszkodtak-az-allomason-athalado-vonaton-video-2': No scheme supplied. Perhaps you meant https:///utazas/2024/02/ahol-csak-lehetett-emberek-kapaszkodtak-az-allomason-athalado-vonaton-video-2?
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
# Hiba a cikk letöltése közben: Invalid URL '/gazdasag/20240219/olyan-nyomas-ala-kerul-magyarorszag-pillanatokon-belul-aminek-evekig-fizethetjuk-az-arat-669301': No scheme supplied. Perhaps you meant https:///gazdasag/20240219/olyan-nyomas-ala-kerul-magyarorszag-pillanatokon-belul-aminek-evekig-fizethetjuk-az-arat-669301?
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   articles = articles.append({'page_url': url, 'url': article_url, 'title': link.text.strip(), 'text': article_text}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   articles = articles.append({'page_url': url, 'url': article_url, 'title': link.text.strip(), 'text': article_text}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   articles = articles.append({'page_url': url, 'url': article_url, 'title': link.text.strip(), 'text': article_text}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   articles = articles.append({'page_url': url, 'url': article_url, 'title': link.text.strip(), 'text': article_text}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   articles = articles.append({'page_url': url, 'url': article_url, 'title': link.text.strip(), 'text': article_text}, ignore_index=True)
# <ipython-input-10-6dd478b89908>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   web_pages = web_pages.append({'url': url, 'title': title}, ignore_index=True)
n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\n\n\nA post shared by Kagney Linn Karter (@flyingspreadies76)\n\n\n\n\n\n\n\n\nA Sun brit bulvárlap \ncikke\n megemlíti a Karter barátai által indított online adománygyűjtést, a GoFundMe-oldalon a többi közt azt \nírják\n róla a hozzá közel állók, hogy sikerei és tehetsége ellenére Kagney mentális egészségügyi problémákkal küzdött az utóbbi években.\n\n\nA cikkből kiderül, hogy Karter a pornózás előtt Missouriban volt táncosnő, majd Kaliforniába költözött, hogy színészi és énekesi karrierje kiteljesedhessen. A felnőttfilmek világában 2008 óta volt jelen. Szerepelt a Hustler magazin címlapján, feltűnt a BBC felnőttiparról szóló, \nTwilight of the Porn Stars\n című dokumentumfilmjében is .\n\n\n\n\n\n\n\xa0\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nView this post on Instagram\n\n\n\n\n\n\n\n\n\n\n\n\n\n ...

# %% [markdown]
# #A huggingface keretrendszer pipeline segítségével készítsünk egy summarizer-t és a dataframe egy elemén teszteljük le.
#
# Használjuk a "NYTK/summarization-hi-mbart-large-50-hungarian" modelljét

# %%
from transformers import pipeline

summarization = pipeline(task="summarization", model="NYTK/summarization-hi-mbart-large-50-hungarian")

print(summarization(input_text)[0]["summary_text"])
# Out:
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-73a491573ab9> in <cell line: 5>()
#       3 summarization = pipeline(task="summarization", model="NYTK/summarization-hi-mbart-large-50-hungarian")
#       4
# ----> 5 print(summarization(input_text)[0]["summary_text"])
#
# NameError: name 'input_text' is not defined

# %% [markdown]
# #A szövegek 1020 tokenre vágása

# %%
def tokenizer_short(text):
  model_inputs = tokenizer(text, max_length=1020)
  return tokenizer.decode(model_inputs["input_ids"])

# %% [markdown]
# #Ellenőrízzük le a fenti függvény működését

# %%
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# [{'summary_text': 'A lakástulajdonosok több mint 85 százaléka rendelkezik lakásbiztosítással . A legtöbben azért kötnek biztosítást , hogy biztonságban tudja az ingatlanát és a benne lévő értékeket. 46 százalékuk bérbe adja lakását, számukra kiemelten fontos, hogy így téríttessék vissza az esetleg károkat, amit a bérlő okozott. A válaszadók 60 százaléka kiemelte a gyors és hatékony kárrendezési folyamat fontosságát.'}]

# %% [markdown]
# #Iteráljuk végig a dataframe-en az összegzőt!

# %%
articles
# Out:
#                    page_url  \
# 0      https://www.napi.hu/
# 1      https://www.napi.hu/
# 2            https://24.hu/
# 3           https://mno.hu/
# 4  https://magyarnemzet.hu/
#
#                                                  url  \
# 0  https://www.economx.hu/kulfold/eu-kulugyminisz...
# 1  https://www.economx.hu/ingatlan/allianz-lakasb...
# 2  https://24.hu/tudomany/2024/02/20/tuzgomb-mete...
# 3  https://mandiner.hu/kulfold/2024/02/az-usa-meg...
# 4  https://mandiner.hu/kulfold/2024/02/az-usa-meg...
#
#                                                title  \
# 0  Az EU-tagállamok közül csak Magyarország nem á...
# 1  A tűz és a víz a lakástulajok legnagyobb rémál...
# 2         Látványos tűzgömb jelent meg Anglia felett
# 3  Az USA megvétózta az ENSZ-határozatot – nem le...
# 4  Az USA megvétózta az ENSZ-határozatot – nem le...
#
#                                                 text  \
# 0   Az EU-tagállamok közül csak Magyarország nem ...
# 1   A tűz és a víz a lakástulajok legnagyobb rémá...
# 2   Látványos tűzgömb jelent meg Anglia felett | ...
# 3   Az USA megvétózta az ENSZ-határozatot – nem l...
# 4   Az USA megvétózta az ENSZ-határozatot – nem l...
#
#                                           summarized
# 0  Az Európai Unió 26 tagállama közös nyilatkozat...
# 1  Nem csak az ingóságok és az ingatlan védelme, ...
# 2  Megjelent az égen az angliai Lincolnshire és K...
# 3  Az Egyesült Államok megvétózta az ENSZ-határoz...
# 4  Az Egyesült Államok megvétózta az ENSZ-határoz...

# %% [markdown]
# #Küldjük ki az eredményt az ügyfeleknek
# Prompt: egy pandas  dataframeben tárolom releváns cikkek url jét és egy text mezőbe az összegzést. Írj egy python kódot ami ezekből készít egy emailt ami tartalmazza  cikk linkjét és rövid összefoglalóját

# %%
html = """
<html>
<head>
<title>Releváns cikkek összefoglalója</title>
</head>
<body>
<h1>Releváns cikkek összefoglalója</h1>
<p>Ez az email a legfrissebb releváns cikkeket foglalja össze.</p>
<ul>
"""

for i in range(len(articles)):
  html += f"""
  <li>
    <h2>{articles['title'].iloc[i]}</h2>
    <p><a href="{articles['url'].iloc[i]}">{articles['url'].iloc[i]}</a></p>
    <p>{articles['summarized'].iloc[i]}</p>
  </li>
  """

html += """
</ul>
</body>
</html>
"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'summarized'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-72ce2ddcba35> in <cell line: 12>()
#      15     <h2>{articles['title'].iloc[i]}</h2>
#      16     <p><a href="{articles['url'].iloc[i]}">{articles['url'].iloc[i]}</a></p>
# ---> 17     <p>{articles['summarized'].iloc[i]}</p>
#      18   </li>
#      19   """
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'summarized'

# %%
from IPython.display import HTML, display  # Itt importáljuk a HTML függvényt


display(HTML(html))
# Out:
# <html>
# <head>
# <title>Releváns cikkek összefoglalója</title>
# </head>
# <body>
# <h1>Releváns cikkek összefoglalója</h1>
# <p>Ez az email a legfrissebb releváns cikkeket foglalja össze.</p>
# <ul>
#
#   <li>
#     <h2>Az EU-tagállamok közül csak Magyarország nem állt ki az azonnali gázai tűzszünet mellett</h2>
#     <p><a href="https://www.economx.hu/kulfold/eu-kulugyminiszterek-szijjarto-izrael-dontes.785480.html">https://www.economx.hu/kulfold/eu-kulugyminiszterek-szijjarto-izrael-dontes.785480.html</a></p>
#     <p>Az Európai Unió 26 tagállama közös nyilatkozatban követeli Izraeltől az azonnali humanitárius tűzszünetet a Gázai övezetben , és felszólítja a Rafah határvárosban összezsúfolt civilek védelmére. Magyarország nem támogatta a felhívást , így az utolsó pillanatban kisiklatta az EU tervét , hogy az kollektív szankciókat szabjon ki az erőszakos izraeli telepesekre.</p>
#   </li>
#
#   <li>
#     <h2>A tűz és a víz a lakástulajok legnagyobb rémálma
# Nem csak az ingóságok és az ingatlan védelme, de a jó ár-érték arány és az asszisztencia...</h2>
#     <p><a href="https://www.economx.hu/ingatlan/allianz-lakasbiztositas-ingatlan-biztonsag-segitsegnyujtas-felmeres-kutatas.785496.html">https://www.economx.hu/ingatlan/allianz-lakasbiztositas-ingatlan-biztonsag-segitsegnyujtas-felmeres-kutatas.785496.html</a></p>
#     <p>Nem csak az ingóságok és az ingatlan védelme, de a jó ár-érték arány és az asszisztencia szolgáltatások is fontos szempont, amikor biztosítást választunk. Ez derült ki az Allianz kutatásából , valamint az Economx.hu Adatvédelmi tájékoztatójából is .</p>
#   </li>
#
#   <li>
#     <h2>Látványos tűzgömb jelent meg Anglia felett</h2>
#     <p><a href="https://24.hu/tudomany/2024/02/20/tuzgomb-meteor-urszemet-anglia-video/">https://24.hu/tudomany/2024/02/20/tuzgomb-meteor-urszemet-anglia-video/</a></p>
#     <p>Megjelent az égen az angliai Lincolnshire és Kelet-Yorkshire fölött megfigyelt meteortűzgömb , amely nem egy űrszemét , hanem egy használaton kívüli űreszköz darabja lehetett . Kapcsolódó Földi lézerrel pusztítanák el az űrszemetet Egyre nagyobb problémát jelent az űrszemét, egy japán cég pedig meglepő megoldással állt elő. A reggeli hírekből szemezgettünk .</p>
#   </li>
#
#   <li>
#     <h2>Az USA megvétózta az ENSZ-határozatot – nem lesz tűzszünet Gázában</h2>
#     <p><a href="https://mandiner.hu/kulfold/2024/02/az-usa-megvetozta-az-ensz-hatarozatot-nem-lesz-tuzszunet-gazaban?utm_campaign=mandiner_cikkajanlo&utm_medium=referral&utm_source=magyarnemzet.hu">https://mandiner.hu/kulfold/2024/02/az-usa-megvetozta-az-ensz-hatarozatot-nem-lesz-tuzszunet-gazaban?utm_campaign=mandiner_cikkajanlo&utm_medium=referral&utm_source=magyarnemzet.hu</a></p>
#     <p>Az Egyesült Államok megvétózta az ENSZ-határozatot – nem lesz tűzszünet Gázában ! Az ukrán kormány lenyomta a vegyi fegyvereket az oroszok és az oroszok által bevetett ukrajnai szakadárok ellen ! Az ukrán elnök és a külügyminiszter nagyon örül , hogy megmenekült Kijevből a Jobbik és a Fidesz elnöke ! Az amerikaiak nem ugranak be Magyarországra , és szeretnék , ha az Index tudósítója nem írja meg a legfontosabb híreket .</p>
#   </li>
#
#   <li>
#     <h2>Az USA megvétózta az ENSZ-határozatot – nem lesz tűzszünet Gázában</h2>
#     <p><a href="https://mandiner.hu/kulfold/2024/02/az-usa-megvetozta-az-ensz-hatarozatot-nem-lesz-tuzszunet-gazaban?utm_campaign=mandiner_cikkajanlo&utm_medium=referral&utm_source=magyarnemzet.hu">https://mandiner.hu/kulfold/2024/02/az-usa-megvetozta-az-ensz-hatarozatot-nem-lesz-tuzszunet-gazaban?utm_campaign=mandiner_cikkajanlo&utm_medium=referral&utm_source=magyarnemzet.hu</a></p>
#     <p>Az Egyesült Államok megvétózta az ENSZ-határozatot – nem lesz tűzszünet Gázában ! Az ukrán kormány lenyomta a vegyi fegyvereket az oroszok és az oroszok által bevetett ukrajnai szakadárok ellen ! Az ukrán elnök és a külügyminiszter nagyon örül , hogy megmenekült Kijevből a Jobbik és a Fidesz elnöke ! Az amerikaiak nem ugranak be Magyarországra , és szeretnék , ha az Index tudósítója nem írja meg a legfontosabb híreket .</p>
#   </li>
#
# </ul>
# </body>
# </html>
